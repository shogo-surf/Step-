# %%
import pandas as pd
df = pd.read_csv("meguro_raw_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       名称    カテゴリー        アドレス              アクセス  築年数   構造  階数  \
# 0           0  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  築4年  4階建  4階
# 1           1  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  築4年  4階建  4階
# 2           2  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  築4年  4階建  4階
# 3           3  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  築4年  4階建  1階
# 4           4  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  築4年  4階建  1階
#
#        家賃     管理費 敷金 礼金    間取り       面積  \
# 0  11.9万円  10000円  -  -  ワンルーム   24.4m2
# 1  18.3万円       -  -  -    2DK  40.75m2
# 2  18.3万円  12000円  -  -   1LDK  40.75m2
# 3  19.7万円  12000円  -  -  1SLDK  45.66m2
# 4  20.2万円  12000円  -  -   2LDK  45.66m2
#
#                                           URL
# 0  https://suumo.jp/chintai/jnc_000076002819/
# 1  https://suumo.jp/chintai/jnc_000086717111/
# 2  https://suumo.jp/chintai/jnc_000085963153/
# 3  https://suumo.jp/chintai/jnc_000086509846/
# 4  https://suumo.jp/chintai/jnc_000076540745/

# %%
#数値データへの変換
#「家賃」「管理費」「敷金」「礼金」「面積」「築年数」
import re
def get_number(value):
    n = re.findall(r"[0-9.]+", value)
    
    if len(n)!=0:
        return float(n[0])
    else:
        return 0

df["家賃"] = df["家賃"].apply(get_number)
df["管理費"] = df["管理費"].apply(get_number)
#単位を万円に統一
df["管理費"] = df["管理費"] / 10000
df["敷金"] = df["敷金"].apply(get_number)
df["礼金"] = df["礼金"].apply(get_number)
df["面積"] = df["面積"].apply(get_number)
df["築年数"] = df["築年数"].apply(get_number)

# %%
df.head()
# Out:
#    Unnamed: 0       名称    カテゴリー        アドレス              アクセス  築年数   構造  階数  \
# 0           0  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 1           1  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 2           2  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 3           3  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  1階
# 4           4  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  1階
#
#      家賃  管理費   敷金   礼金    間取り     面積  \
# 0  11.9  1.0  0.0  0.0  ワンルーム  24.40
# 1  18.3  0.0  0.0  0.0    2DK  40.75
# 2  18.3  1.2  0.0  0.0   1LDK  40.75
# 3  19.7  1.2  0.0  0.0  1SLDK  45.66
# 4  20.2  1.2  0.0  0.0   2LDK  45.66
#
#                                           URL
# 0  https://suumo.jp/chintai/jnc_000076002819/
# 1  https://suumo.jp/chintai/jnc_000086717111/
# 2  https://suumo.jp/chintai/jnc_000085963153/
# 3  https://suumo.jp/chintai/jnc_000086509846/
# 4  https://suumo.jp/chintai/jnc_000076540745/

# %%
#アクセスから「沿線」「駅」「徒歩」を抽出(徒歩は数値データに変換)
# 沿線を抽出
df["沿線"] = df["アクセス"].apply(lambda x: x.split("/")[0])

# アクセスから駅を抽出
df["駅"] = df["アクセス"].apply(lambda x: x.split(" ")[0].split("/")[1])

# アクセスから徒歩を抽出
df["徒歩"] = df["アクセス"].apply(lambda x: int(re.findall(r"[0-9]+", x.split(" ")[1])[0]))

# %%
df.head()
# Out:
#    Unnamed: 0       名称    カテゴリー        アドレス              アクセス  築年数   構造  階数  \
# 0           0  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 1           1  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 2           2  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  4階
# 3           3  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  1階
# 4           4  PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  4.0  4階建  1階
#
#      家賃  管理費   敷金   礼金    間取り     面積  \
# 0  11.9  1.0  0.0  0.0  ワンルーム  24.40
# 1  18.3  0.0  0.0  0.0    2DK  40.75
# 2  18.3  1.2  0.0  0.0   1LDK  40.75
# 3  19.7  1.2  0.0  0.0  1SLDK  45.66
# 4  20.2  1.2  0.0  0.0   2LDK  45.66
#
#                                           URL     沿線      駅  徒歩
# 0  https://suumo.jp/chintai/jnc_000076002819/  東急目黒線  武蔵小山駅  21
# 1  https://suumo.jp/chintai/jnc_000086717111/  東急目黒線  武蔵小山駅  21
# 2  https://suumo.jp/chintai/jnc_000085963153/  東急目黒線  武蔵小山駅  21
# 3  https://suumo.jp/chintai/jnc_000086509846/  東急目黒線  武蔵小山駅  21
# 4  https://suumo.jp/chintai/jnc_000076540745/  東急目黒線  武蔵小山駅  21

# %%
#重複の排除

# "URL", "アクセス"をキーに重複データを削除
df.drop_duplicates(subset=["URL", "アクセス"], inplace=True)

# %%
#その他もキーに重複を削除
df.drop_duplicates(subset=["名称", "カテゴリー", "アドレス", "築年数", "構造", "階数", "家賃", "管理費", "敷金", "礼金", "間取り", "面積", "沿線", "駅", "徒歩"], inplace=True)

# %%
df
# Out:
#      Unnamed: 0        名称    カテゴリー        アドレス              アクセス   築年数  \
# 0             0   PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分   4.0
# 1             1   PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分   4.0
# 2             2   PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分   4.0
# 3             3   PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分   4.0
# 4             4   PASEO目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分   4.0
# ..          ...       ...      ...         ...               ...   ...
# 244         244  トレステージ目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  20.0
# 245         245  トレステージ目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  20.0
# 246         246  トレステージ目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  20.0
# 247         247  トレステージ目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  20.0
# 250         250  トレステージ目黒  賃貸マンション  東京都目黒区下目黒２  東急目黒線/武蔵小山駅 歩21分  20.0
#
#             構造   階数    家賃  管理費     敷金    礼金    間取り      面積  \
# 0          4階建   4階  11.9  1.0    0.0   0.0  ワンルーム   24.40
# 1          4階建   4階  18.3  0.0    0.0   0.0    2DK   40.75
# 2          4階建   4階  18.3  1.2    0.0   0.0   1LDK   40.75
# 3          4階建   1階  19.7  1.2    0.0   0.0  1SLDK   45.66
# 4          4階建   1階  20.2  1.2    0.0   0.0   2LDK   45.66
# ..         ...  ...   ...  ...    ...   ...    ...     ...
# 244  地下2地上18階建  10階  22.2  0.0   44.4  22.2   1LDK   50.35
# 245  地下2地上18階建  13階  22.5  0.0   45.0  22.5   1LDK   50.35
# 246  地下2地上18階建   4階  23.0  0.0   46.0  23.0   1LDK   55.02
# 247  地下2地上18階建  16階  49.8  0.0   99.6  49.8   4LDK  118.00
# 250  地下2地上18階建  16階  51.7  0.0  103.4  51.7   4LDK  118.00
#
#                                             URL     沿線      駅  徒歩
# 0    https://suumo.jp/chintai/jnc_000076002819/  東急目黒線  武蔵小山駅  21
# 1    https://suumo.jp/chintai/jnc_000086717111/  東急目黒線  武蔵小山駅  21
# 2    https://suumo.jp/chintai/jnc_000085963153/  東急目黒線  武蔵小山駅  21
# 3    https://suumo.jp/chintai/jnc_000086509846/  東急目黒線  武蔵小山駅  21
# 4    https://suumo.jp/chintai/jnc_000076540745/  東急目黒線  武蔵小山駅  21
# ..                                          ...    ...    ...  ..
# 244  https://suumo.jp/chintai/jnc_000085347346/  東急目黒線  武蔵小山駅  21
# 245  https://suumo.jp/chintai/jnc_000086613957/  東急目黒線  武蔵小山駅  21
# 246  https://suumo.jp/chintai/jnc_000083031247/  東急目黒線  武蔵小山駅  21
# 247  https://suumo.jp/chintai/jnc_000086292822/  東急目黒線  武蔵小山駅  21
# 250  https://suumo.jp/chintai/jnc_000083991802/  東急目黒線  武蔵小山駅  21
#
# [230 rows x 18 columns]

# %%
df.to_csv("meguro_raw_data_整形.csv")

# %%
pip install oauth2client
# Out:
# Requirement already satisfied: oauth2client in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (4.1.3)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\pures\appdata\local\programs\python\python311\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Google Sheetsへのアクセスを設定
scope = ['https://www.googleapis.com/auth/spreadsheets']
creds = ServiceAccountCredentials.from_json_keyfile_name(r'C:\Users\pures\Downloads\dulcet-bastion-397400-b8ae94b5ff05.json', scope)
client = gspread.authorize(creds)

# %%
def write_df_to_sheet(dataframe, sheet_name, start_cell='A1'):
    sheet = client.open('SUUMOスクレイピング整形データ').sheet1

    # データをGoogle Sheetsに書き込む
    data = dataframe.values.tolist()
    sheet.append_rows(data)

# %%
# DataFrameのデータをGoogle Sheetsに書き込む
write_df_to_sheet(df, 'SUUMOスクレイピング整形データ')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\auth\transport\requests.py:186, in Request.__call__(self, url, method, body, headers, timeout, **kwargs)
#     185 _LOGGER.debug("Making request: %s %s", method, url)
# --> 186 response = self.session.request(
#     187     method, url, data=body, headers=headers, timeout=timeout, **kwargs
#     188 )
#     189 return _Response(response)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# The above exception was the direct cause of the following exception:
#
# TransportError                            Traceback (most recent call last)
# c:\Users\pures\OneDrive\ドキュメント\Step③\SUUMO-スクレイピング\データ整形.ipynb セル 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # DataFrameのデータをGoogle Sheetsに書き込む
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> write_df_to_sheet(df, 'SUUMOスクレイピング整形データ')
#
# c:\Users\pures\OneDrive\ドキュメント\Step③\SUUMO-スクレイピング\データ整形.ipynb セル 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> def write_df_to_sheet(dataframe, sheet_name, start_cell='A1'):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     sheet = client.open('SUUMOスクレイピング整形データ').sheet1
#       <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     # データをGoogle Sheetsに書き込む
#       <a href='vscode-notebook-cell:/c%3A/Users/pures/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Step%E2%91%A2/SUUMO-%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0/%E3%83%87%E3%83%BC%E3%82%BF%E6%95%B4%E5%BD%A2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     data = dataframe.values.tolist()
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\gspread\client.py:183, in Client.open(self, title, folder_id)
#     167 def open(self, title, folder_id=None):
#     168     """Opens a spreadsheet.
#     169
#     170     :param str title: A title of a spreadsheet.
#    (...)
#     181     >>> gc.open('My fancy spreadsheet')
#     182     """
# --> 183     spreadsheet_files, response = self._list_spreadsheet_files(title, folder_id)
#     184     try:
#     185         properties = finditem(
#     186             lambda x: x["name"] == title,
#     187             spreadsheet_files,
#     188         )
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\gspread\client.py:156, in Client._list_spreadsheet_files(self, title, folder_id)
#     153 if page_token:
#     154     params["pageToken"] = page_token
# --> 156 response = self.request("get", url, params=params)
#     157 response_json = response.json()
#     158 files.extend(response_json["files"])
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\gspread\client.py:80, in Client.request(self, method, endpoint, params, data, json, files, headers)
#      70 def request(
#      71     self,
#      72     method,
#    (...)
#      78     headers=None,
#      79 ):
# ---> 80     response = getattr(self.session, method)(
#      81         endpoint,
#      82         json=json,
#      83         params=params,
#      84         data=data,
#      85         files=files,
#      86         headers=headers,
#      87         timeout=self.timeout,
#      88     )
#      90     if response.ok:
#      91         return response
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\auth\transport\requests.py:538, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535 remaining_time = max_allowed_time
#     537 with TimeoutGuard(remaining_time) as guard:
# --> 538     self.credentials.before_request(auth_request, method, url, request_headers)
#     539 remaining_time = guard.remaining_timeout
#     541 with TimeoutGuard(remaining_time) as guard:
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\auth\credentials.py:175, in Credentials.before_request(self, request, method, url, headers)
#     171 # pylint: disable=unused-argument
#     172 # (Subclasses may use these arguments to ascertain information about
#     173 # the http request.)
#     174 if not self.valid:
# --> 175     self.refresh(request)
#     176 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     177 self.apply(headers)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\oauth2\service_account.py:438, in Credentials.refresh(self, request)
#     436 else:
#     437     assertion = self._make_authorization_grant_assertion()
# --> 438     access_token, expiry, _ = _client.jwt_grant(
#     439         request, self._token_uri, assertion
#     440     )
#     441     self.token = access_token
#     442     self.expiry = expiry
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\oauth2\_client.py:308, in jwt_grant(request, token_uri, assertion, can_retry)
#     284 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     285
#     286 For more details, see `rfc7523 section 4`_.
#    (...)
#     304 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     305 """
#     306 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 308 response_data = _token_endpoint_request(
#     309     request,
#     310     token_uri,
#     311     body,
#     312     can_retry=can_retry,
#     313     headers={
#     314         metrics.API_CLIENT_HEADER: metrics.token_request_access_token_sa_assertion()
#     315     },
#     316 )
#     318 try:
#     319     access_token = response_data["access_token"]
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\oauth2\_client.py:268, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     229 def _token_endpoint_request(
#     230     request,
#     231     token_uri,
#    (...)
#     237     **kwargs
#     238 ):
#     239     """Makes a request to the OAuth 2.0 authorization server's token endpoint.
#     240
#     241     Args:
#    (...)
#     265             an error.
#     266     """
# --> 268     response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     269         request,
#     270         token_uri,
#     271         body,
#     272         access_token=access_token,
#     273         use_json=use_json,
#     274         can_retry=can_retry,
#     275         headers=headers,
#     276         **kwargs
#     277     )
#     278     if not response_status_ok:
#     279         _handle_error_response(response_data, retryable_error)
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\oauth2\_client.py:215, in _token_endpoint_request_no_throw(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     209     retryable_error = _can_retry(
#     210         status_code=response.status, response_data=response_data
#     211     )
#     213     return False, response_data, retryable_error
# --> 215 request_succeeded, response_data, retryable_error = _perform_request()
#     217 if request_succeeded or not retryable_error or not can_retry:
#     218     return request_succeeded, response_data, retryable_error
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\oauth2\_client.py:191, in _token_endpoint_request_no_throw.<locals>._perform_request()
#     190 def _perform_request():
# --> 191     response = request(
#     192         method="POST", url=token_uri, headers=headers_to_use, body=body, **kwargs
#     193     )
#     194     response_body = (
#     195         response.data.decode("utf-8")
#     196         if hasattr(response.data, "decode")
#     197         else response.data
#     198     )
#     199     response_data = ""
#
# File c:\Users\pures\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\auth\transport\requests.py:192, in Request.__call__(self, url, method, body, headers, timeout, **kwargs)
#     190 except requests.exceptions.RequestException as caught_exc:
#     191     new_exc = exceptions.TransportError(caught_exc)
# --> 192     raise new_exc from caught_exc
#
# TransportError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
